# %% [raw]
# 1. Conduct LASSO regression of Y on X. Select the optimal penalty according to 10-fold
# cross-validation. What is the preferred model in this approach? What is the predictive performance of your model as a function of the penalty parameter? What variables
# get selected with non-zero coefficients? Interpret your findings.

# %% [raw]
# 2. Forecast returns using 1 to 5 principal components X. Construct a table with a column
# for each model specification, and rows that report predictive coefficients, t-stats, and
# R2. Interpret your findings.

# %% [raw]
# 6. Construct out-of-sample forecasts using the following models:
# (a) The cross-validated LASSO model For each model, hold parameters fixed based on the in-sample estimation (i.e., using
# only data through 2010). Report out-of-sample predictive R2 for each method. See
# Kelly and Pruitt (2013) or Gu, Kelly, and Xiu (2020) if you need guidance on this.
